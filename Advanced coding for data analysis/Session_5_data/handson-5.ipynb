# %% [markdown]
# Python for Data & Analytics<br>
# Session 5, Hands-on Exercise Solution

# %% [markdown]
# Exercise 5-1
# *** requires datafiles: SP500_Constituents.csv

# %%
# 1) Read the file SP500_Constituents.csv into a DataFrame
#    use the Symbol as the DataFrame's index
#    display the DataFrame

# %%
# 2)Access a particular DataFrame column name "Security" in SP500_Constituents
# Out:
# Symbol
# MMM              3M Company
# ABT     Abbott Laboratories
# ABBV            AbbVie Inc.
# ABMD            ABIOMED Inc
# ACN           Accenture plc
#                ...
# YUM         Yum! Brands Inc
# ZBRA     Zebra Technologies
# ZBH           Zimmer Biomet
# ZION          Zions Bancorp
# ZTS                  Zoetis
# Name: Security, Length: 505, dtype: object

# %%
# 3)Access entire row by index name (row name): 'MMM'
# Out:
# Security                               3M Company
# SEC filings                               reports
# GICS Sector                           Industrials
# GICS Sub-Industry        Industrial Conglomerates
# Headquarters Location         St. Paul, Minnesota
# Date first added                       1976-08-09
# CIK                                         66740
# Founded                                      1902
# Name: MMM, dtype: object

# %%
# 4)Access paticular data by index name (row name) and column: 'MMM'and'GICS Sector'
#What is the result

# %%
# 5)Locate missing data in SP500_Constituents
#  Which columns have missing values?

# %%
# 6)Locate missing data of column 'Founded' with a filter expression
# Out:
#                   Security SEC filings  GICS Sector         GICS Sub-Industry  \
# Symbol
# L              Loews Corp.     reports   Financials      Multi-line Insurance
# ROP     Roper Technologies     reports  Industrials  Industrial Conglomerates
# SBAC    SBA Communications     reports  Real Estate         Specialized REITs
#
#        Headquarters Location Date first added      CIK Founded
# Symbol
# L         New York, New York              NaN    60086     NaN
# ROP        Sarasota, Florida       2009-12-23   882835     NaN
# SBAC     Boca Raton, Florida       2017-09-01  1034054     NaN

# %% [markdown]
# Exercise 5-2
# *** requires datafiles: EcarSalesByCountryAndYear.csv, countries.csv

# %%
# 1) Read the file EcarSalesByCountryAndYear.csv into a DataFrame
#    use the Country as the DataFrame's index
#    display the DataFrame
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017
# Country
# Canada              87700      51376      50960      44150      18746
# China             3334000    1246000    1204000    1016002     579000
# France             315978     194881      69466      53745      42799
# Germany            681410     394632     108839      67504      54492
# Japan               44296      29000      43867      52013      54100
# Netherlands         95464      89362      67520      29187      11085
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# United Kingdom     305281     175082      72584      59911      49182
# United States      607567     297939     329528     361307     199818

# %%
# 2) Calculate the sales growth between the last two years
#    and append this to the DataFrame as a column called 'Growth'
#    (LaterYear/BeforeYear)-1
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017  \
# Country
# Canada              87700      51376      50960      44150      18746
# China             3334000    1246000    1204000    1016002     579000
# France             315978     194881      69466      53745      42799
# Germany            681410     394632     108839      67504      54492
# Japan               44296      29000      43867      52013      54100
# Netherlands         95464      89362      67520      29187      11085
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# United Kingdom     305281     175082      72584      59911      49182
# United States      607567     297939     329528     361307     199818
#
#                   Growth
# Country
# Canada          0.707023
# China           1.675762
# France          0.621389
# Germany         0.726697
# Japan           0.527448
# ...

# %%
# 3) Display the DataFrame sorted by Growth, from high to low
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017  \
# Country
# China             3334000    1246000    1204000    1016002     579000
# United States      607567     297939     329528     361307     199818
# United Kingdom     305281     175082      72584      59911      49182
# Germany            681410     394632     108839      67504      54492
# Canada              87700      51376      50960      44150      18746
# France             315978     194881      69466      53745      42799
# Japan               44296      29000      43867      52013      54100
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# Netherlands         95464      89362      67520      29187      11085
#
#                   Growth
# Country
# China           1.675762
# United States   1.039233
# United Kingdom  0.743646
# Germany         0.726697
# Canada          0.707023
# ...

# %%
# 4) Create a new DataFrame called dfRecent, with only columns Sales2021 and Sales2020
# Out:
#                 Sales2021  Sales2020
# Country
# Canada              87700      51376
# China             3334000    1246000
# France             315978     194881
# Germany            681410     394632
# Japan               44296      29000
# Netherlands         95464      89362
# Norway             167949     113588
# Sweden             138033      96054
# United Kingdom     305281     175082
# United States      607567     297939

# %%
# 5) From dfRecent, use a filter to display only United States and Canada
# Out:
#                Sales2021  Sales2020
# Country
# Canada             87700      51376
# United States     607567     297939

# %%
# 6) Read the file countries.csv into a DataFrame
#    use the Country as the DataFrame's index
#    display the DataFrame
# Out:
#                Continent
# Country
# Canada           AMERICA
# China               ASIA
# France            EUROPE
# Germany           EUROPE
# Japan               ASIA
# Netherlands       EUROPE
# Norway            EUROPE
# Sweden            EUROPE
# United Kingdom    EUROPE
# United States    AMERICA

# %%
# 7) Join countries.csv into a EcarSalesByCountryAndYear.csv DataFrame
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017  \
# Country
# Canada              87700      51376      50960      44150      18746
# China             3334000    1246000    1204000    1016002     579000
# France             315978     194881      69466      53745      42799
# Germany            681410     394632     108839      67504      54492
# Japan               44296      29000      43867      52013      54100
# Netherlands         95464      89362      67520      29187      11085
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# United Kingdom     305281     175082      72584      59911      49182
# United States      607567     297939     329528     361307     199818
#
#                   Growth Continent
# Country
# Canada          0.707023   AMERICA
# China           1.675762      ASIA
# France          0.621389    EUROPE
# ...

# %%
# 8) Delete 'Growth' column
# Out:
#                 Sales2021  Sales2020  Sales2019  Sales2018  Sales2017  \
# Country
# Canada              87700      51376      50960      44150      18746
# China             3334000    1246000    1204000    1016002     579000
# France             315978     194881      69466      53745      42799
# Germany            681410     394632     108839      67504      54492
# Japan               44296      29000      43867      52013      54100
# Netherlands         95464      89362      67520      29187      11085
# Norway             167949     113588      88443      86290      71737
# Sweden             138033      96054      41784      29909      19793
# United Kingdom     305281     175082      72584      59911      49182
# United States      607567     297939     329528     361307     199818
#
#                Continent
# Country
# Canada           AMERICA
# China               ASIA
# France            EUROPE
# Germany           EUROPE
# Japan               ASIA
# ...
